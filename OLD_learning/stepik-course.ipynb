# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sp = pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
sp
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sp.loc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
sp.iloc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
ds = pd.read_csv("https://stepik.org/media/attachments/course/4852/titanic.csv")

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sp[(sp["writing score"] > 100) & (sp.gender == 'female')]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
ds = pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
ds
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
lunch = ds[ds.lunch == "free/reduced"].shape[0]

# %%
lunch / ds.index.size
# Out:
# 0.355

# %%
red = ds[ds.lunch == "free/reduced"]
norm = ds[ds.lunch == "standart"]

# %%
ds.groupby(["lunch"]).mean()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
ds.groupby(["lunch"]).var()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced  229.824270     221.871139     238.202881
# standard      186.418089     191.285560     205.620887

# %%
heroes = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")

# %%
heroes.groupby("legs").count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
charge = pd.read_csv("https://stepik.org/media/attachments/course/4852/accountancy.csv")
charge.columns
# Out:
# Index(['Unnamed: 0', 'Executor', 'Type', 'Salary'], dtype='object')

# %%
g = charge.groupby(['Executor', 'Type']).Salary.mean()

# %%
g
# Out:
# Executor  Type
# Loopa     A        58.000000
#           B       145.166667
#           C       154.333333
#           D       137.714286
#           E       164.000000
#           F       238.000000
# Pupa      A       160.833333
#           B        77.000000
#           C        74.500000
#           D       146.500000
#           E       131.200000
#           F       136.250000
# Name: Salary, dtype: float64

# %%
heroes.groupby(["attack_type", "primary_attr"]).aggregate({"id" : "count"}).sort_values("id")
# Out:
#                           id
# attack_type primary_attr
# Melee       int            2
# Ranged      str            3
#             agi           18
# Melee       agi           19
#             str           35
# Ranged      int           40

# %%
tree = pd.read_csv("http://stepik.org/media/attachments/course/4852/algae.csv")

# %%
tree
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
tree[tree.genus == "Fucus"].alanin.describe()
# Out:
# count    3.000000
# mean     3.566411
# std      3.149943
# min      0.346431
# 25%      2.028965
# 50%      3.711498
# 75%      5.176401
# max      6.641303
# Name: alanin, dtype: float64

# %%
tree.groupby("group").sucrose.describe()
# Out:
#        count      mean       std       min       25%      50%       75%  \
# group
# brown    6.0  4.709666  2.336471  1.636122  3.070321  5.00397  6.773014
# green    3.0  4.008792  1.634817  2.452623  3.157047  3.86147  4.786877
# red      1.0  0.704580       NaN  0.704580  0.704580  0.70458  0.704580
#
#             max
# group
# brown  6.825467
# green  5.712284
# red    0.704580

# %%
heroes.legs.hist()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
plt.plot(df.index, df.income)

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['income'].plot()
# Out:
# <AxesSubplot:>

# %%
colors = pd.read_csv("https://stepik.org/media/attachments/course/4852/genome_matrix.csv", index_col = 0)

# %%
g = sns.heatmap(colors, cmap="viridis")# ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
heroes['roles']
# Out:
# 0                           ['Carry', 'Escape', 'Nuker']
# 1        ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2            ['Support', 'Disabler', 'Nuker', 'Durable']
# 3      ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4            ['Support', 'Disabler', 'Nuker', 'Jungler']
#                              ...
# 112         ['Carry', 'Escape', 'Disabler', 'Initiator']
# 113           ['Support', 'Nuker', 'Disabler', 'Escape']
# 114    ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 115           ['Support', 'Nuker', 'Disabler', 'Escape']
# 116        ['Carry', 'Initiator', 'Disabler', 'Durable']
# Name: roles, Length: 117, dtype: object

# %%
heroes['roles'].str.split(",").str.len().value_counts().sort_index()
# Out:
# 1     1
# 2     9
# 3    28
# 4    38
# 5    33
# 6     8
# Name: roles, dtype: int64

# %%
heroes['roles'].str.split(",").str.len().value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
d = {'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]}

# %%
df = pd.DataFrame(data=d)
df
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
data = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
data
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
data.head(10).iloc[:10:, 0::2]
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
data.drop(index=[0,4],columns=['V1', 'V3'])
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
data.loc[(data['V1'] >= 0) & (data['V3'] == 'A')]
# Out:
#      V1    V2 V3   V4
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 6     0   9.0  A  2.0
# 7     1   9.0  A  1.0
# ..   ..   ... ..  ...
# 493   0   9.0  A  1.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [183 rows x 4 columns]

# %%
data.loc[(data['V2'] != 10) | (data['V4'] >= 1)]
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
my_stat = data.assign(V5 = lambda x: x.V1 + x.V4)
my_stat
# Out:
#      V1    V2 V3   V4   V5
# 0     2  13.0  B  1.0  3.0
# 1    -1   7.0  B  1.0  0.0
# 2     0  11.0  A  0.0  0.0
# 3     2  11.0  A  2.0  4.0
# 4     0  10.0  B -1.0 -1.0
# ..   ..   ... ..  ...  ...
# 495   1   8.0  A -1.0  0.0
# 496   3   8.0  A  1.0  4.0
# 497  -1  11.0  B  2.0  1.0
# 498   1  11.0  A  2.0  3.0
# 499   0   8.0  B  1.0  1.0
#
# [500 rows x 5 columns]

# %%
my_stat = my_stat.assign(V6 = np.log(my_stat['V2']))
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = my_stat.rename(columns={'V1':'session_value', 'V2':'group', 'V3':'time', 'V4':'n_users'})

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

my_stat['session_value'].fillna(0, inplace=True)
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat.loc[(my_stat['n_users'] >= 0)]['n_users'].median()
# Out:
# 5.0

# %%
my_stat['n_users'].mask(my_stat['n_users'] < 0, my_stat.n_users[(my_stat['n_users'] >= 0)].median(), inplace=True)

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
my_stat = my_stat.groupby('group', as_index=False).agg({'session_value' : 'mean'})
my_stat = my_stat.rename(columns={'session_value':'mean_session_value'})
my_stat
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8

# %%
data = pd.read_clipboard(sep=',')

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [Гвардии Сомали]
# Index: []

# %%
data['date'] = pd.to_datetime(data.timestamp, unit='s')
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c8fd6e068b15> in <module>
# ----> 1 data['date'] = pd.to_datetime(data.timestamp, unit='s')
#       2 data.head()
#
# F:\Programs\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'timestamp'

# %%
data['day'] = data.date.dt.date

# %%
data

# %%
data[['user_id', 'day']].drop_duplicates().groupby('user_id').agg({'day': 'count'}).sort_values('day')
